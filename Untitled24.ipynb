# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return (x+3)**2

# %%
def grad_f(x):
    return 2*(x+3)

# %%
def gradient_descent(start_x=2,learning_rate=0.1,max_itr=50,tol=1e-6):
    x=start_x
    x_history=[x]
    for i in range(max_itr):
        gradient=grad_f(x)
        x_new=x-learning_rate*gradient
        x_history.append(x_new)
        if abs(x_new-x)<tol:
            break
        x=x_new
    return x,f(x),x_history

# %%
min_x,min_y,x_steps=gradient_descent()
print("Local maximum ata x",min_x)
print("Minimum value y =", min_y)
# Out:
# Local maximum ata x -2.9999286376153647
# Minimum value y = 5.092589940842615e-09

# %%
x_vals = np.linspace(-6, 2, 100)
y_vals = f(x_vals)

# %%
plt.plot(x_vals, y_vals, label='y = (x+3)^2')
plt.scatter(x_steps, [f(x) for x in x_steps], color='red', label='Gradient Descent Steps')
plt.title("Gradient Descent to find Local Minima")
# Out:
# Text(0.5, 1.0, 'Gradient Descent to find Local Minima')
